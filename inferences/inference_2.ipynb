# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
plt.rcParams["figure.dpi"] = 300

# %%
algo_names = ["BFS_v2", "DFS_V2", "UCS"]
dataframes = [pd.read_csv(f"../results/{algo_names[i]}_data.csv").drop(columns=["Unnamed: 0"]) for i in range(3)]

# %%
dataframes[1] #DFS
# Out:
#                                                  path  expanded_node  \
# 0   ['Up', 'Left', 'Down', 'Down', 'Left', 'Up', '...           5644
# 1   ['Up', 'Right', 'Down', 'Down', 'Left', 'Up', ...         164549
# 2   ['Up', 'Right', 'Down', 'Down', 'Left', 'Up', ...             25
# 3   ['Up', 'Up', 'Left', 'Down', 'Down', 'Right', ...          59807
# 4   ['Up', 'Up', 'Left', 'Down', 'Down', 'Right', ...          66819
# ..                                                ...            ...
# 95  ['Down', 'Down', 'Left', 'Up', 'Up', 'Right', ...          29318
# 96  ['Up', 'Up', 'Left', 'Down', 'Down', 'Right', ...            354
# 97  ['Up', 'Up', 'Left', 'Down', 'Down', 'Right', ...             27
# 98  ['Down', 'Down', 'Left', 'Up', 'Up', 'Right', ...         165372
# 99                                           ['Left']         181438
#
#     fringe_size  depth
# 0          4373   5501
# 1         16009  66056
# 2            22     25
# 3         36333  52269
# ...

# %%
dataframes[-2].describe() #DFS
# Out:
#        expanded_node  fringe_size       depth
# count      100.00000   100.000000  100.000000
# mean       149.66000    97.080000    6.470000
# std        211.57477   130.113834    2.743054
# min          1.00000     2.000000    1.000000
# 25%         14.50000    13.000000    4.000000
# 50%         54.50000    41.000000    6.000000
# 75%        172.25000   105.000000    8.000000
# max       1080.00000   637.000000   12.000000

# %%
dataframes[-3].describe() #BFS
# Out:
#        expanded_node  fringe_size       depth
# count      100.00000   100.000000  100.000000
# mean       149.66000    97.080000    6.470000
# std        211.57477   130.113834    2.743054
# min          1.00000     2.000000    1.000000
# 25%         14.50000    13.000000    4.000000
# 50%         54.50000    41.000000    6.000000
# 75%        172.25000   105.000000    8.000000
# max       1080.00000   637.000000   12.000000

# %%
dataframes[-1].describe() #UCS
# Out:
#        expanded_node  fringe_size       depth
# count      100.00000   100.000000  100.000000
# mean       149.66000   164.720000    5.540000
# std        211.57477   219.843015    2.664469
# min          1.00000     3.000000    1.000000
# 25%         14.50000    21.000000    3.000000
# 50%         54.50000    69.000000    5.000000
# 75%        172.25000   187.000000    7.000000
# max       1080.00000  1098.000000   11.000000

# %%
# Plot the arrays
plt.plot(dataframes[0].index, dataframes[0]["fringe_size"], label='fringe size BFS', alpha=0.5)
plt.plot(dataframes[1].index, dataframes[1]["fringe_size"], label='fringe size DFS', alpha=0.5)
plt.plot(dataframes[2].index, dataframes[2]["fringe_size"], label='fringe size UCS', alpha=0.5)


# Add labels and legend
plt.xlabel('Scenarios')
plt.ylabel('Fringe Size')
plt.legend()

# Show the plot
plt.show()

# %%
# Plot the arrays
plt.plot(dataframes[0].index, dataframes[0]["fringe_size"], label='fringe size BFS', alpha=0.5)
plt.plot(dataframes[1].index, dataframes[1]["fringe_size"], label='fringe size DFS', alpha=0.5)
plt.plot(dataframes[2].index, dataframes[2]["fringe_size"], label='fringe size UCS', alpha=0.5)


# Add labels and legend
plt.xlabel('Scenarios')
plt.ylabel('Fringe Size')
plt.legend()

# Show the plot
plt.show()

# %%
# Plot the arrays
plt.plot(dataframes[0].index, dataframes[0]["expanded_node"], label='expanded node BFS', alpha=0.5)
plt.plot(dataframes[1].index, dataframes[1]["expanded_node"], label='expanded node DFS', alpha=0.5)
plt.plot(dataframes[2].index, dataframes[2]["expanded_node"], label='expanded node UCS', alpha=0.5)


# Add labels and legend
plt.xlabel('Scenarios')
plt.ylabel('Expanded Node')
plt.legend()


# Show the plot
plt.show()

# %%
# Plot the arrays
plt.plot(dataframes[0].index, dataframes[0]["depth"], label='depth BFS', alpha=0.5)
plt.plot(dataframes[1].index, dataframes[1]["depth"], label='depth DFS', alpha=0.5)
plt.plot(dataframes[2].index, dataframes[2]["depth"], label='depth UCS', alpha=0.5)


# Add labels and legend
plt.xlabel('Scenarios')
plt.ylabel('Depth')
plt.legend()
# Show the plot
plt.show()
